# %%
Announcement: Mastertheorem muss nicht auswendig gelernt werden! Anwenden können reicht!

# %%
Erste Klausurenphase?

Algorithmnus Klausurvorbereitung:
    1. Geht das Skript durch (wenn ihr noch mehr als 7 Tage Zeit habt, bis zu Klausur, schreibt ne Zusammenfassung)
    2. Arbeitet alle Übungsblätter selbständig durch - ohne auf die Lösung zu schauen
    3. Arbeitet die GAF Altklausuren selbständig durch.
    4. Zurück zu Schritt 1.

# %%
Graphen III / Paradigmen - I

Kapitel 6 - Programmier Paradigmen: 
    ->Letztes Kapitel - Enthält verschiedene Sachen, die alle 
    nicht in eines der anderen Kapitel gepasst haben
    
    ->Klausurrelevant!

# %%
Backtracking 
    ->depth first

Flussnetzwerke

# %%
12.1. Backtracking

# %%
(a) Geben Sie eine Lösung für das 5 Damenproblem an. Berechnen Sie diese mittels Backtracking.

# %%
from IPython.display import Image
Image("/home/jonas/Dropbox/Spring19/a/0 ALGODAT/12/1.png")

# %%
b) Wie groß ist die Komplexitat für das n Damenproblem, wenn ein naiver Algorithmus für die Berechnung
der Lösung verwendet wird?

# %%
Die Komplexität ist eine Teilmenge von n! und damit O(n!). 
Sie berechnet sich durch die Anzahl der möglichen Positionierungen der Damen. 
Für die 1. Zeile sind es n mögliche Positionen, für die 2.  n − 1
mögliche Positionen (etwas weniger eigentlich, allerdings vernachlässigen wir hier die Diagonalen, da es
reicht, die Obermenge anzugeben), . . . , für die n-te Zeile gibt es nur noch (maximal) eine Position. Damit
n·(n−1)· . . . ·1 = n!.

# %%
c) Weiterhin Sei eine modifizierte Version eines Sudokus mit jeweils nur 4 anstelle von 9 Feldern gegeben.
Wie bei dem originalen Sudoku gilt, dass in jeder Zeile, in jeder Spalte und in jedem Block (2x2 Unterquadrat) 
die Zahlen 1 bis 4 nur einmal vorkommen durfen. Gegeben Sei nun folgendes Sudoku:

# %%
from IPython.display import Image
Image("/home/jonas/Dropbox/Spring19/a/0 ALGODAT/12/2.png")

# %%
i) Geben Sie generell grob einen naiven Algorithmus in Pseudocode an, der mittels Backtracking eine
Lösung berechnen kann. Tipp: Es muss nicht über alle Spalten und Zeilen iteriert werden, sondern 
es reicht eine Betrachtung der freien Felder.

# %%
Algorithmus sudoku(int[][] sudokuBrett, Feld[] freieFelder, int freiesFeldZahl)):
    if istZahlAufBrettDoppelt(sudokuBrett):
        return false
    if freiesFeldZahl == freieFelder.length:
        return true
    for zahl = 1 bis 4:
        freiesFeld = freieFelder[freiesFeldZahl]
        sudokuBrett[freiesFeld.zeile][freiesFeld.spalte] = zahl
        if sudoku(sudokuBrett, freiesFeldZahl + 1):
            return true
    return false

Die Ausführung startet mit sudoku(sudokuBrett, freieFelder, 0)

# %%
ii) Berechnen Sie die (eindeutige) Lösung des obigen Sudokus mit Hilfe des erstellten Algorithmus. 
Geben Sie dabei alle Zwischenschritte an, wobei es reicht, die anfangs noch leeren Felder anzugeben. 
Im folgenden sollen die freien Felder von links nach rechts und dann von oben nach unten
betrachtet werden, also wie in gewohnter deutscher Schreib-/Leserichtung (wobei jede beliebige
Abfolge dieser Felder möglich wäre).

# %%
from IPython.display import Image
Image("/home/jonas/Dropbox/Spring19/a/0 ALGODAT/12/3.png")

# %%
12.2. Flussnetzwerke
Gegeben sei das folgende Flussnetzwerk:

# %%
from IPython.display import Image
Image("/home/jonas/Dropbox/Spring19/a/0 ALGODAT/12/4.png")

# %%
12.2. a)

# %%
Zeichnen Sie das Residualnetzwerk zu dem oben gegebenen Flussnetzwerk in die Vorlage ein.

# %%
Vorlage:

# %%
from IPython.display import Image
Image("/home/jonas/Dropbox/Spring19/a/0 ALGODAT/12/5.png")

# %%
Lösung:

# %%
from IPython.display import Image
Image("/home/jonas/Dropbox/Spring19/a/0 ALGODAT/12/6.png")

# %%
b) Bestimmen Sie den maximalen Fluss des obigen Flussnetzwerkes mit Hilfe des Min-Cut-Max-FlowTheorems und 
kennzeichnen Sie den Schnitt des maximalen Flusses deutlich in dem Flussnetzwerk.

# %%
from IPython.display import Image
Image("/home/jonas/Dropbox/Spring19/a/0 ALGODAT/12/7.png")

# %%
Nächste Woche noch:
    - Dynamische Programmierung VS Naiv Rekursiv am Bsp Edit-Distanz
    - Greedy Algorithmen
    - Dynamische Programmierung am Bsp des NP-Vollständen Rucksackproblems
